# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from pandas import read_csv
df=read_csv('/content/Top 1000 Bollywood Movies and their boxoffice.csv')
df
# Out:
#      Unnamed: 0    SN                       Movie    Worldwide   India Net  \
# 0             0     1                     Pathaan  10500000000  5240000000
# 1             1     2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2             2     3               KGF Chapter 2  12080000000  4350000000
# 3             3     4                      Dangal  20700000000  3740000000
# 4             4     5                       Sanju   5880000000  3420000000
# ..          ...   ...                         ...          ...         ...
# 995         995   996                     Nikamma            0    20000000
# 996         996   997                    Saugandh     30000000    20000000
# 997         997   998                 Akaash Vani     30000000    20000000
# 998         998   999                     Zwigato     10000000    20000000
# 999         999  1000                      FryDay     20000000    20000000
#
#      India Gross     Overseas      Budget               Verdict
# ...

# %%
print(df.dtypes)
# Out:
# Unnamed: 0      int64
# SN              int64
# Movie          object
# Worldwide       int64
# India Net       int64
# India Gross     int64
# Overseas        int64
# Budget          int64
# Verdict        object
# dtype: object

# %%
print(df.describe())
# Out:
#         Unnamed: 0           SN     Worldwide     India Net   India Gross  \
# count  1000.000000  1000.000000  1.000000e+03  1.000000e+03  1.000000e+03
# mean    499.500000   500.500000  1.832870e+09  4.079600e+08  6.126900e+08
# std     288.819436   288.819436  1.049006e+10  5.783055e+08  9.814085e+08
# min       0.000000     1.000000  0.000000e+00  2.000000e+07  0.000000e+00
# 25%     249.750000   250.750000  1.600000e+08  9.000000e+07  1.400000e+08
# 50%     499.500000   500.500000  3.700000e+08  2.000000e+08  3.100000e+08
# 75%     749.250000   750.250000  9.025000e+08  4.600000e+08  6.825000e+08
# max     999.000000  1000.000000  1.897000e+11  5.240000e+09  1.416000e+10
#
#            Overseas        Budget
# count  1.000000e+03  1.000000e+03
# mean   9.714300e+08  5.889000e+08
# std    8.596981e+09  2.101992e+09
# min    0.000000e+00  0.000000e+00
# 25%    1.000000e+07  8.000000e+07
# 50%    5.000000e+07  2.000000e+08
# 75%    1.500000e+08  4.000000e+08
# ...

# %%
df2=df[0:6]
df2
# Out:
#    Unnamed: 0  SN                       Movie    Worldwide   India Net  \
# 0           0   1                     Pathaan  10500000000  5240000000
# 1           1   2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2           2   3               KGF Chapter 2  12080000000  4350000000
# 3           3   4                      Dangal  20700000000  3740000000
# 4           4   5                       Sanju   5880000000  3420000000
# 5           5   6                          PK   7920000000  3400000000
#
#    India Gross     Overseas      Budget               Verdict
# 0   6570000000   3920000000  2500000000  All Time Blockbuster
# 1  14160000000   3710000000  2500000000  All Time Blockbuster
# 2  10000000000   2070000000  1000000000  All Time Blockbuster
# 3   5350000000  15350000000   700000000  All Time Blockbuster
# 4   4380000000   1500000000  1000000000  All Time Blockbuster
# 5   4890000000   3030000000   850000000  All Time Blockbuster

# %%
cp=df.copy()
cp
# Out:
#      Unnamed: 0    SN                       Movie    Worldwide   India Net  \
# 0             0     1                     Pathaan  10500000000  5240000000
# 1             1     2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2             2     3               KGF Chapter 2  12080000000  4350000000
# 3             3     4                      Dangal  20700000000  3740000000
# 4             4     5                       Sanju   5880000000  3420000000
# ..          ...   ...                         ...          ...         ...
# 995         995   996                     Nikamma            0    20000000
# 996         996   997                    Saugandh     30000000    20000000
# 997         997   998                 Akaash Vani     30000000    20000000
# 998         998   999                     Zwigato     10000000    20000000
# 999         999  1000                      FryDay     20000000    20000000
#
#      India Gross     Overseas      Budget
# ...

# %%
a=(cp.dropna())
a
# Out:
#      Unnamed: 0    SN                       Movie    Worldwide   India Net  \
# 0             0     1                     Pathaan  10500000000  5240000000
# 1             1     2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2             2     3               KGF Chapter 2  12080000000  4350000000
# 3             3     4                      Dangal  20700000000  3740000000
# 4             4     5                       Sanju   5880000000  3420000000
# ..          ...   ...                         ...          ...         ...
# 995         995   996                     Nikamma            0    20000000
# 996         996   997                    Saugandh     30000000    20000000
# 997         997   998                 Akaash Vani     30000000    20000000
# 998         998   999                     Zwigato     10000000    20000000
# 999         999  1000                      FryDay     20000000    20000000
#
#      India Gross     Overseas      Budget
# ...

# %%
df = pd.DataFrame({"Rank":[38542,33629,32789,54325], 
                   "Year":["2014","2015","2016","2020"], 
                   "Class":["12", "11", "10","9"]})
df['Rank'].plot(kind='box', title='ranks')
plt.show()

# %%
df=read

# %%
df = pd.DataFrame({"Rank":[38542,33629,32789,54325], 
                   "Year":["2014","2015","2016","2020"], 
                   "Class":["12", "11", "10","9"]})
df['Rank'].plot(kind='line')
# Out:
# <Axes: >

# %%
df = pd.DataFrame({"Rank":[38542,33629,32789,54325], 
                   "Year":["2014","2015","2016","2020"], 
                   "Class":["12", "11", "10","9"]})
df['Rank'].plot(kind='pie')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df = pd.DataFrame({"Rank":[38542,33629,32789,54325], 
                   "Year":["2014","2015","2016","2020"], 
                   "Class":["12", "11", "10","9"]})
df['Rank'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df = pd.DataFrame({"Rank":[38542,33629,32789,54325], 
                   "Year":["2014","2015","2016","2020"], 
                   "Class":["12", "11", "10","9"]})
df['Rank'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df = pd.DataFrame({"Rank":[38542,33629,32789,54325], 
                   "Year":["2014","2015","2016","2020"], 
                   "Class":["12", "11", "10","9"]})
df['Rank'].plot(kind='barh')
# Out:
# <Axes: >

# %%
a=df["Budget"]
a
# Out:
# 0      2500000000
# 1      2500000000
# 2      1000000000
# 3       700000000
# 4      1000000000
#           ...
# 995      10000000
# 996      20000000
# 997     100000000
# 998      10000000
# 999     150000000
# Name: Budget, Length: 1000, dtype: int64
